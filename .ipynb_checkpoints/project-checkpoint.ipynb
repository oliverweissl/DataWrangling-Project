# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# %%
start = "2023-01-01"
end = "2023-01-08"

# %%
def percent_diff(col1,col2):
    return ((col2 - col1) / col1) * 100

# %%
path = "Stocks.xlsx"
df = pd.read_excel(path)
del df['Unnamed: 1']

# %%
df.head(5)
# Out:
#               Company    NMS   NMS2  NYQ      GER     FRA      BER      DUS  \
# 0             Ryanair  RYAAY    NaN  NaN  RY4C.DE  RY4C.F  RY4D.BE  RY4D.DU
# 1               Tesla   TSLA    NaN  NaN   TL0.DE     NaN      NaN      NaN
# 2             Netflix   NFLX    NaN  NaN   NFC.DE     NaN      NaN      NaN
# 3              Google   GOOG  GOOGL  NaN  ABEA.DE     NaN      NaN      NaN
# 4  Berkshire Hathaway  BRK-B  BRK-A  NaN      NaN     NaN      NaN      NaN
#
#       ISE      NEO  ...      VIE     VIE2  SGO  LSE  IOB  SAO  STO  JPX  HKG  \
# 0  RYA.IR      NaN  ...      NaN      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1     NaN  TSLA.NE  ...      NaN      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2     NaN  NFLX.NE  ...      NaN      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3     NaN  GOOG.NE  ...      NaN      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4     NaN      NaN  ...  BRKB.VI  BRKA.VI  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#    KSC
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# ...

# %%
# Only Tickers that are on NMS and GER
ny_ger = df.loc[df["NMS"].notnull() & df["GER"].notnull(), ["NMS", "GER"]]
ny_ger_tups = list(ny_ger.itertuples(index=False, name=None))

# download each pair of Tickers and plot them
for tup in ny_ger_tups:
    stocks = ' '.join([tup[0], tup[1]])
    data = yf.download(stocks, start, end, interval='1m')
    data['Open'].plot(figsize=(16,12))

# # get a list of all the Tickers to download
# stocks = ' '.join(' '.join([tup[0], tup[1]]) for tup in ny_ger_tups)
# data = yf.download(stocks, start, end, interval='1m')
# Out:
# [*********************100%***********************]  2 of 2 completed
# [*********************100%***********************]  2 of 2 completed
# [*********************100%***********************]  2 of 2 completed
# [*********************100%***********************]  2 of 2 completed
# [*********************100%***********************]  2 of 2 completed
# [*********************100%***********************]  2 of 2 completed
# [*********************100%***********************]  2 of 2 completed
# [*********************100%***********************]  2 of 2 completed
# [*********************100%***********************]  2 of 2 completed
# [*********************100%***********************]  2 of 2 completed
# [*********************100%***********************]  2 of 2 completed
# [*********************100%***********************]  2 of 2 completed
# [*********************100%***********************]  2 of 2 completed
# [*********************100%***********************]  2 of 2 completed

# %%
# Only Tickers that are on NYQ and HKG
ny_hkg = df.loc[df["NYQ"].notnull() & df["HKG"].notnull(), ["NYQ", "HKG"]]

ny_hkg_tups = list(ny_hkg.itertuples(index=False, name=None))

# download each pair of Tickers and plot them
for tup in ny_hkg_tups:
    stocks = ' '.join([tup[0], tup[1]])
    data = yf.download(stocks, start, end, interval='1m')
    data['Open'].plot(figsize=(16,12))
# Out:
# [*********************100%***********************]  2 of 2 completed
# [*********************100%***********************]  2 of 2 completed

# %%
# Only Tickers that are on BUE and JPX
ger_jpx = df.loc[df["BUE"].notnull() & df["JPX"].notnull(), ["BUE", "JPX"]]

ger_jpx_tups = list(ger_jpx.itertuples(index=False, name=None))

# download each pair of Tickers and plot them
for tup in ger_jpx_tups:
    stocks = ' '.join([tup[0], tup[1]])
    data = yf.download(stocks, start, end, interval='1m')
    data['Open'].plot(figsize=(16,12))
# Out:
# [*********************100%***********************]  2 of 2 completed
# [*********************100%***********************]  2 of 2 completed
# [*********************100%***********************]  2 of 2 completed
